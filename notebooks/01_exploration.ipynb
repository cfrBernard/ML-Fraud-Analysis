# %%
# %%
import pandas as pd

df = pd.read_csv("../data/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df["Amount"].describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
df["Class"].value_counts()
# 0,6%
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df["Class"].value_counts(normalize=True)
# Out:
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %%
df[df["Amount"] == 0.0].shape
# Out:
# (1825, 31)

# %%
df[df["Amount"] == 0.0]["Class"].value_counts()
# 1,5%
# Out:
# Class
# 0    1798
# 1      27
# Name: count, dtype: int64

# %%
# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Graph 1 : distribution des montants (transactions normales)
plt.figure(figsize=(10, 4))
sns.histplot(df[df["Class"] == 0]["Amount"], bins=100, log_scale=(False, True))
plt.title("Montant des transactions normales (log scale Y)")
plt.show()

# Graph 2 : distribution des montants (fraudes)
plt.figure(figsize=(10, 4))
sns.histplot(df[df["Class"] == 1]["Amount"], bins=100, log_scale=(False, True), color="red")
plt.title("Montant des fraudes (log scale Y)")
plt.show()

# %%
# %%
correlation_matrix = df.corr(numeric_only=True)
correlation_matrix
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %%
# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 12))
sns.heatmap(correlation_matrix, cmap="coolwarm", center=0, annot=False)
plt.title("Matrice de corrélation")
plt.show()

# %%
# Compte le nombre de fraudes avec un montant > 2000
fraudes_sup_2000 = df[(df['Class'] == 1) & (df['Amount'] > 2000)]

print(f"Nombre de fraudes > 2000 : {len(fraudes_sup_2000)}")
print(fraudes_sup_2000[['Time', 'Amount', 'Class']])
# Out:
# Nombre de fraudes > 2000 : 1
#             Time   Amount  Class
# 176049  122608.0  2125.87      1

# %%
import numpy as np
import pandas as pd

def scan_fraud_zones(df, variables, bins=10, min_rate=0.01, max_rate=0.15, min_count=30):
    results = {}
    for var in variables:
        vals = df[var].dropna()
        min_val, max_val = vals.min(), vals.max()
        bins_edges = np.linspace(min_val, max_val, bins + 1)

        suspicious_zones = []

        for i in range(bins):
            low, high = bins_edges[i], bins_edges[i+1]
            segment = df[(df[var] >= low) & (df[var] < high)]
            count = len(segment)
            if count < min_count:
                continue
            fraud_rate = segment['Class'].mean()
            if min_rate <= fraud_rate <= max_rate:
                suspicious_zones.append({
                    'range': (low, high),
                    'fraud_rate': fraud_rate,
                    'count': count
                })

        if suspicious_zones:
            results[var] = suspicious_zones

    return results


# Exemple
variables_of_interest = ['V4', 'V10', 'V11', 'V12', 'V14', 'V17']
zones = scan_fraud_zones(df, variables_of_interest, bins=20, min_rate=0.70, max_rate=0.90, min_count=20)

for var, zones_list in zones.items():
    print(f"\nVariable: {var}")
    for zone in zones_list:
        print(f"  Range: {zone['range']}, Fraud rate: {zone['fraud_rate']*100:.2f}%, Count: {zone['count']}")
# Out:
# Variable: V11
#   Range: (np.float64(4.451539190732038), np.float64(5.29235852305291)), Fraud rate: 78.69%, Count: 61
#
# Variable: V12
#   Range: (np.float64(-14.703898626995965), np.float64(-13.377293291546522)), Fraud rate: 76.67%, Count: 30
#   Range: (np.float64(-9.397477285198185), np.float64(-8.07087194974874)), Fraud rate: 88.10%, Count: 42
#   Range: (np.float64(-8.07087194974874), np.float64(-6.7442666142992955)), Fraud rate: 76.27%, Count: 59
#   Range: (np.float64(-6.7442666142992955), np.float64(-5.417661278849851)), Fraud rate: 88.24%, Count: 68
#
# Variable: V14
#   Range: (np.float64(-14.753161758954484), np.float64(-13.266107181852178)), Fraud rate: 90.00%, Count: 30
#   Range: (np.float64(-13.266107181852178), np.float64(-11.779052604749873)), Fraud rate: 80.00%, Count: 30
#   Range: (np.float64(-11.779052604749873), np.float64(-10.291998027647569)), Fraud rate: 79.55%, Count: 44
# ...

# %%
import numpy as np
import pandas as pd

def scan_fraud_zones(df, variables, bins=10, min_rate=0.01, max_rate=0.15, min_count=30):
    results = {}
    for var in variables:
        vals = df[var].dropna()
        min_val, max_val = vals.min(), vals.max()
        bins_edges = np.linspace(min_val, max_val, bins + 1)

        suspicious_zones = []

        for i in range(bins):
            low, high = bins_edges[i], bins_edges[i+1]
            segment = df[(df[var] >= low) & (df[var] < high)]
            count = len(segment)
            if count < min_count:
                continue
            fraud_rate = segment['Class'].mean()
            if min_rate <= fraud_rate <= max_rate:
                suspicious_zones.append({
                    'range': (low, high),
                    'fraud_rate': fraud_rate,
                    'count': count
                })

        if suspicious_zones:
            results[var] = suspicious_zones

    return results


# Exemple
variables_of_interest = ['V4', 'V10', 'V11', 'V12', 'V14', 'V17']
zones = scan_fraud_zones(df, variables_of_interest, bins=20, min_rate=0.10, max_rate=0.70, min_count=50)

for var, zones_list in zones.items():
    print(f"\nVariable: {var}")
    for zone in zones_list:
        print(f"  Range: {zone['range']}, Fraud rate: {zone['fraud_rate']*100:.2f}%, Count: {zone['count']}")
# Out:
# Variable: V4
#   Range: (np.float64(5.596086417713775), np.float64(6.724012179302149)), Fraud rate: 28.63%, Count: 241
#   Range: (np.float64(6.724012179302149), np.float64(7.851937940890521)), Fraud rate: 44.87%, Count: 78
#   Range: (np.float64(7.851937940890521), np.float64(8.979863702478895)), Fraud rate: 56.86%, Count: 51
#
# Variable: V10
#   Range: (np.float64(-10.0882428698769), np.float64(-7.6715729419818)), Fraud rate: 65.00%, Count: 60
#   Range: (np.float64(-7.6715729419818), np.float64(-5.2549030140867)), Fraud rate: 66.67%, Count: 117
#   Range: (np.float64(-5.2549030140867), np.float64(-2.8382330861916003)), Fraud rate: 23.01%, Count: 665
#
# Variable: V11
#   Range: (np.float64(2.769900526090291), np.float64(3.610719858411165)), Fraud rate: 10.59%, Count: 680
#   Range: (np.float64(3.610719858411165), np.float64(4.451539190732038)), Fraud rate: 59.17%, Count: 120
#
# Variable: V12
# ...

# %%
import numpy as np
import pandas as pd

def scan_fraud_zones(df, variables, bins=10, min_rate=0.01, max_rate=0.15, min_count=30):
    results = {}
    for var in variables:
        vals = df[var].dropna()
        min_val, max_val = vals.min(), vals.max()
        bins_edges = np.linspace(min_val, max_val, bins + 1)

        suspicious_zones = []

        for i in range(bins):
            low, high = bins_edges[i], bins_edges[i+1]
            segment = df[(df[var] >= low) & (df[var] < high)]
            count = len(segment)
            if count < min_count:
                continue
            fraud_rate = segment['Class'].mean()
            if min_rate <= fraud_rate <= max_rate:
                suspicious_zones.append({
                    'range': (low, high),
                    'fraud_rate': fraud_rate,
                    'count': count
                })

        if suspicious_zones:
            results[var] = suspicious_zones

    return results


# Exemple
variables_of_interest = ['V4', 'V10', 'V11', 'V12', 'V14', 'V17']
zones = scan_fraud_zones(df, variables_of_interest, bins=20, min_rate=0.01, max_rate=0.15, min_count=200)

for var, zones_list in zones.items():
    print(f"\nVariable: {var}")
    for zone in zones_list:
        print(f"  Range: {zone['range']}, Fraud rate: {zone['fraud_rate']*100:.2f}%, Count: {zone['count']}")
# Out:
# Variable: V4
#   Range: (np.float64(3.340234894537031), np.float64(4.468160656125403)), Fraud rate: 1.25%, Count: 6024
#   Range: (np.float64(4.468160656125403), np.float64(5.596086417713775)), Fraud rate: 3.79%, Count: 1477
#
# Variable: V11
#   Range: (np.float64(1.9290811937694174), np.float64(2.769900526090291)), Fraud rate: 1.12%, Count: 5179
#   Range: (np.float64(2.769900526090291), np.float64(3.610719858411165)), Fraud rate: 10.59%, Count: 680
#
# Variable: V12
#   Range: (np.float64(-4.091055943400406), np.float64(-2.764450607950959)), Fraud rate: 1.60%, Count: 4436
#
# Variable: V14
#   Range: (np.float64(-4.3437797192383485), np.float64(-2.8567251421360425)), Fraud rate: 2.29%, Count: 1965
#
# Variable: V17
#   Range: (np.float64(4.091077407503203), np.float64(5.811893688493086)), Fraud rate: 2.80%, Count: 214

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Liste des colonnes à visualiser
features = [col for col in df.columns if col not in ["Time", "Class"]]

for feature in features:
    plt.figure(figsize=(14, 6))

    # KDE Plot
    plt.subplot(1, 2, 1)
    sns.kdeplot(df[df["Class"] == 0][feature], label="Non-Fraud", fill=True)
    sns.kdeplot(df[df["Class"] == 1][feature], label="Fraud", fill=True, color="red")
    plt.title(f"KDE Plot - {feature}")
    plt.legend()

    # Box Plot
    plt.subplot(1, 2, 2)
    sns.boxplot(x="Class", y=feature, data=df)
    plt.title(f"Boxplot - {feature}")

    plt.tight_layout()
    plt.show()
